# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
class DataRead1(object):
    def __init__(self, file_path):
        self.file_path = pd.read_csv(file_path)

    def file_read(self):
        return self.file_path

    def RowSelect(self):
        row_1 = int(input('Enter index of the row 1: '))
        row_2 = int(input('Enter index of row 2: '))
        row_12 = self.file_path.iloc[[row_1, row_2], :]
        return row_12

class DataRead2(DataRead1):
    def correlation(self):
        corr = self.file_path.corr()
        sns.heatmap(corr)

    def RowSelect(self):
        row_1 = int(input('Enter index of the row 1: '))
        row_2 = int(input('Enter index of row 2: '))
        row_3 = int(input('Enter index of row 3: '))
        row_123 = self.file_path.iloc[[row_1, row_2, row_3], :]
        return row_123

# %%
Path = r"C:\Users\sarth\Documents\Sample projects\datasets\housing\housing.csv"
housing = DataRead1(Path)

# %%
housing.file_read()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing.RowSelect()
# Out:
# Enter index of the row 1: 12
# Enter index of row 2: 23
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12    -122.26     37.85                52.0       2491.0           474.0
# 23    -122.27     37.84                52.0       1688.0           337.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 23       853.0       325.0         2.1806             99700.0        NEAR BAY

# %%
housing = DataRead2(Path)

# %%
housing.correlation()

# %%
housing.RowSelect()
# Out:
# Enter index of the row 1: 12
# Enter index of row 2: 23
# Enter index of row 3: 34
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12    -122.26     37.85                52.0       2491.0           474.0
# 23    -122.27     37.84                52.0       1688.0           337.0
# 34    -122.27     37.83                51.0       2665.0           574.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 23       853.0       325.0         2.1806             99700.0        NEAR BAY
# 34      1258.0       536.0         2.7303            109700.0        NEAR BAY
